# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt
plt.rcParams['figure.figsize'] = [15, 10]

# %%
img = cv2.imread('198f52ca-228e-4ece-a89a-edf239888519.png')
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
plt.imshow(img)

# %%
unsharp = cv2.GaussianBlur(img, ksize=(5, 5), sigmaX=5)
plt.imshow(unsharp)

# %%
diff = img.astype(np.float32) - unsharp.astype(np.float32)

# %%
amount = 5
sharpened = img.astype(np.float32) + diff * amount
sharpened = np.clip(sharpened, 0, 255).astype(np.uint8)
plt.imshow(sharpened)

# %%
# Параметр amount масштабирует высокочастотную составляющую изображения. 
# При его увеличении возрастает вклад границ, однако при слишком больших значениях 
# появляются артефакты в виде ореолов и усиленного шума, резкость становится «искусственной».
# При малом значении параметра amount вклад изображения становится незначительным, 
# поэтому усиление высокочастотных компонентов практически не проявляется, и результат близок к исходному изображению.
# Разумные значения параметра amount находятся в диапазоне от 0.5 до 1.5.
